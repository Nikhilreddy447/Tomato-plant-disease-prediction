# %%
import tensorflow as tf
from tensorflow import keras
import os
import PIL
import glob
import pathlib 
from keras import layers,Sequential
from keras.layers import Conv2D,Dropout,Flatten,BatchNormalization,Dense,MaxPool2D

# %%
train_dir_path = './Tomato/train'
test_dir_path = './Tomato/test'
val_dir_path = './Tomato/val'
train_dir_path = pathlib.Path(train_dir_path)
test_dir_path = pathlib.Path(test_dir_path)
val_dir_path  = pathlib.Path(val_dir_path)
print(train_dir_path,test_dir_path,val_dir_path)
# Out:
# Tomato\train Tomato\test Tomato\val

# %%
train_images = list(train_dir_path.glob('*/*.jpg'))
test_images = list(test_dir_path.glob('*/*.jpg'))
val_images = list(val_dir_path.glob('*/*.jpg'))

# %%
PIL.Image.open(str(train_images[3]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
PIL.Image.open(str(test_images[3]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
PIL.Image.open(str(val_images[5]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>
